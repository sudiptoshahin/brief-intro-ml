# %%
import torch
import matplotlib
import matplotlib.pyplot as plt
import cv2
import numpy as np
import os

# %% [markdown]
# ### Creating pretrained model instance
#
# Model detection

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')

# img = 'https://ultralytics.com/images/zidane.jpg'
dir_path = os.path.dirname(os.path.abspath('__file__'))
img_path = f'{dir_path}/images/'
img1 = f'{img_path}/1.jpeg'
img2 = f'{img_path}/2.jpeg'

results = model(img2)

# %matplotlib inline
# plt.imshow(np.squeeze(results.render()))
# plt.show()
print(results)
# Out:
# Using cache found in /home/sudiptoshahin/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2023-11-24 Python-3.11.5 torch-2.1.2+cu121 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...
# image 1/1: 183x275 21 cars, 4 trucks
# Speed: 12.9ms pre-process, 138.2ms inference, 2.3ms NMS per image at shape (1, 3, 448, 640)

# %%
# show the image
print(results.show())

# get the files
# results.files

img_tensor = torch.tensor(results.ims, dtype=torch.float32, device=torch.device('cpu'))
print(img_tensor.shape)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>
# None
# torch.Size([1, 183, 275, 3])

# %% [markdown]
# #### Real time detections

# %%
# matplotlib.use('Agg')
cap = cv2.VideoCapture(0)
i = 0
while cap.isOpened():
    ret, frame = cap.read()
    # show video
    # cv2.imshow('YOLO', frame)
    

    # show a single frame image
    # %matplotlib inline
    # plt.imshow(np.squeeze(frame))
    # plt.show()

    # run yolo model
    results = model(frame)
    cv2.imshow('YOLO', np.squeeze(results.render()))
    

    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

    # if i > 0:
    #     break
    i = i + 1

cap.release()
cv2.destroyAllWindows()
# Out:
# ...
# QObject::moveToThread: Current thread (0x9d106e0) is not the object's thread (0xe3b77e0).
# Cannot move to target thread (0x9d106e0)
#
# QObject::moveToThread: Current thread (0x9d106e0) is not the object's thread (0xe3b77e0).
# Cannot move to target thread (0x9d106e0)
#
# QObject::moveToThread: Current thread (0x9d106e0) is not the object's thread (0xe3b77e0).
# Cannot move to target thread (0x9d106e0)
#
# QObject::moveToThread: Current thread (0x9d106e0) is not the object's thread (0xe3b77e0).
# Cannot move to target thread (0x9d106e0)
#
# QObject::moveToThread: Current thread (0x9d106e0) is not the object's thread (0xe3b77e0).
# Cannot move to target thread (0x9d106e0)
#
# QObject::moveToThread: Current thread (0x9d106e0) is not the object's thread (0xe3b77e0).
# Cannot move to target thread (0x9d106e0)
#
# QObject::moveToThread: Current thread (0x9d106e0) is not the object's thread (0xe3b77e0).
# Cannot move to target thread (0x9d106e0)
#
# ...

# %% [markdown]
# ### Train

# %%
import uuid
import os
import time

# %%
dir_path = os.path.dirname(os.path.abspath('__file__'))

IMAGE_PATH = os.path.join(dir_path, 'images/data/')
labels = ['awake', 'drowsy']
number_imgs = 20

# %%
cap = cv2.VideoCapture(0)

if cap.isOpened():
    for label in labels:
    # print("Collecting images for {}".format(label))
        time.sleep(2)

        # loop through image range
        for img_num in range(number_imgs):
            print('Collecting images for {}, image number {}'.format(label, img_num))
    
            ret, frame = cap.read()
            imgname = os.path.join(IMAGE_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
    
            # write image to file
            cv2.imwrite(imgname, frame)
            cv2.imshow('Image collection', frame)
            time.sleep(2)

            if cv2.waitKey(10) & 0xFF == ord('q'):
                break

cap.release()
cv2.destroyAllWindows()
# Out:
# ...
# QObject::moveToThread: Current thread (0x8722450) is not the object's thread (0x9b4c1f0).
# Cannot move to target thread (0x8722450)
#
# QObject::moveToThread: Current thread (0x8722450) is not the object's thread (0x9b4c1f0).
# Cannot move to target thread (0x8722450)
#
# QObject::moveToThread: Current thread (0x8722450) is not the object's thread (0x9b4c1f0).
# Cannot move to target thread (0x8722450)
#
# QObject::moveToThread: Current thread (0x8722450) is not the object's thread (0x9b4c1f0).
# Cannot move to target thread (0x8722450)
#
# QObject::moveToThread: Current thread (0x8722450) is not the object's thread (0x9b4c1f0).
# Cannot move to target thread (0x8722450)
#
# QObject::moveToThread: Current thread (0x8722450) is not the object's thread (0x9b4c1f0).
# Cannot move to target thread (0x8722450)
#
# QObject::moveToThread: Current thread (0x8722450) is not the object's thread (0x9b4c1f0).
# Cannot move to target thread (0x8722450)
#
# ...

# %%
for label in labels:
    
    for img_num in range(number_imgs):
        print('Collecting images for {}, image no {}'.format(label, img_num))
        imgname = os.path.join(IMAGE_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        print(imgname)

# %%
# !pip install pyqt5 lxml --upgrade
# !cd labelImg && pyrcc -o libs/resources.py resources.qrc
# Out:
# ...
#   Obtaining dependency information for lxml from https://files.pythonhosted.org/packages/be/2b/c240b9d4b1daf80573adbca0b6e3e3d69bb3838bebd9cb4c7d51ed315189/lxml-4.9.4-cp311-cp311-manylinux_2_28_x86_64.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 967.6 kB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.9.3
#     Uninstalling lxml-4.9.3:
#       Successfully uninstalled lxml-4.9.3
# ...
# zsh:1: command not found: pyrcc

# %%
# !cd yolov5 && python -c "import os; print(os.getcwd())"
# !cd yolov5 && python train.py --img 320 --batch 16 --epochs 500 --data dataset.yml --weights yolov5s.pt --workers 5
# Out:
# train: weights=yolov5s.pt, cfg=, data=dataset.yml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=500, batch_size=16, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=5, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-253-g63555c8 Python-3.11.5 torch-2.1.2+cu121 CPU
#
# ...

# %% [markdown]
# #### Load model

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/runs/train/exp21/weights/last.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /home/sudiptoshahin/.cache/torch/hub/master.zip
# YOLOv5 🚀 2023-12-21 Python-3.11.5 torch-2.1.2+cu121 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7055974 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...

# %%
dir_path = os.path.dirname(os.path.abspath('__file__'))

# %%
dir = f"{dir_path}/yolov5/data"
run_dir = f"{dir_path}/yolov5/runs/"
img = os.path.join(dir, 'images', 'awake.4b153d46-9f1e-11ee-9ebb-709cd14d3bef.jpg')
results = model(img)

results.print()
# results.print()
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()
# Out:
# image 1/1: 480x640 1 awake
# Speed: 8.0ms pre-process, 93.6ms inference, 1.7ms NMS per image at shape (1, 3, 480, 640)

# %%
# !cd yolov5 && python detect.py --weights runs/train/exp20/weights/best.pt
# Out:
# detect: weights=['runs/train/exp20/weights/best.pt'], source=data/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-253-g63555c8 Python-3.11.5 torch-2.1.2+cu121 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7055974 parameters, 0 gradients, 15.9 GFLOPs
# image 1/40 /home/sudiptoshahin/Projects/JupyterNotebookFiles/brief-intro-ml/yolo-detect/yolov5/data/images/awake.3a320914-9f1e-11ee-9ebb-709cd14d3bef.jpg: 480x640 (no detections), 75.6ms
# ...

# %%
# testing realtime
import cv2
import torch
import numpy as np

model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/runs/train/exp21/weights/last.pt', force_reload=True)
cap = cv2.VideoCapture(0)

while cap.isOpened():
    ret, frame = cap.read()

    results = model(frame)

    cv2.imshow('YOLO', np.squeeze(results.render()))
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /home/sudiptoshahin/.cache/torch/hub/master.zip
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 6
#       3 import torch
#       4 import numpy as np
# ----> 6 model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/runs/train/exp21/weights/last.pt', force_reload=True)
#       7 cap = cv2.VideoCapture(0)
#       9 while cap.isOpened():
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/hub.py:563, in load(repo_or_dir, model, source, trust_repo, force_reload, verbose, skip_validation, *args, **kwargs)
#     559     raise ValueError(
#     560         f'Unknown source: "{source}". Allowed values: "github" | "local".')
#     562 if source == 'github':
# --> 563     repo_or_dir = _get_cache_or_reload(repo_or_dir, force_reload, trust_repo, "load",
# ...
